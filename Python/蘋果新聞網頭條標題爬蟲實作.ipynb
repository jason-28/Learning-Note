# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
url='https://tw.appledaily.com/home/' #蘋果新聞網的頭條標題爬取
res=requests.get(url)
soup=BeautifulSoup(res.text,'html.parser')
title=soup.find_all('div', class_='storycard-headline text_greyish-brown-two')
titles=[t.find('span',class_='headline truncate truncate--3').text for t in title]
text=str(titles).replace(' ','\n').replace('\\u3000','').replace('[','').replace(']','')
print(text)
# Out:
# '軍人當眾槍擊前女友胸部36秒奪命影片曝光',
# '獨家｜慟！《鳥來伯》長青因心臟宿疾辭世享壽76歲遺願曝光',
# '「刺青妹吹喇叭片」千人求上車女主角崩潰！老司機竟是閨蜜',
# '病例總整理｜AZ疫苗開打2天全台11老人猝死！死因待查',
# '獨家專訪｜長青女兒悲吐亡父臨終無人相伴晚年回憶「這一生很精采」',
# '人妻引狼入室！老公外遇她找友訴苦卻擦槍走火劇情神展開',
# '疫情殯葬壓力爆表！小冬瓜這回送自己親人一句「火來了快跑」徹底淚崩',
# '防疫記者會陳時中淡淡回應女記者「你很敏銳」！鄉民都嗨了',
# '航警局第一個打AZ的人！炫耀「上班7年過退休生活」惹怒警署工作跟研究所都GG',
# '「疫情不可怕了」他罵陳時中團隊笨透了：撤銷三級警戒吧！',
# '台中94歲翁昨打疫苗今晨喝水竟從嘴邊流出...妻驚覺「人沒有了」',
# 'C羅就是狂！記者會的1個move竟讓可口可樂市值瞬間蒸發40億美元',
# '女星嫁豪門不到3年爆婚變富三代尪不給生冷戰分居',
# '郭台銘BNT疫苗有譜！國台辦正面允諾郭辦回應了',
# '9旬婦打疫苗12小時後猝死沒三高也無慢性病！家屬無奈說這句話',
# '愛國同心會會長周慶峻染疫病逝新黨發言人批「政府殺人」',
# '演藝大亨竟是狼！騙追星女陪睡拍裸照分飾四角被逮辯「開玩笑」',
# '直擊！台南悍女「壁咚」逮捕無罩男自認抓「現行犯」反吃官司',
# '航警炫「每天過退休生活」慘遭免職律師：打官司可能翻盤',
# '男子躺台灣大道警消走近嚇一跳：面目全非死掉了',
# '咬破10斤白酒酒桶偷喝調皮狗醉到只剩眼球轉轉轉',
# '抒壓片│戰痘女醫再發功！婦人胳肢窩生痘痘擠出油黃義大利麵條',
# '人夫偷吃健身房女員工！法官當庭聽她淫叫10秒「應是本人」',
# '香腸伯辭世｜長青《傻女婿》草根味濃挺過心臟死劫二婚小31歲妻',
# '一杯梅酒就倒！男士官寢室性侵女同袍還拍片',
# '香腸伯辭世｜《天天開心》搭擋康弘不捨憶2個月前最後相見',
# '獨家｜驗車系統大當機！民眾排隊苦等2小時怒轟：增加染疫風險',
# '第11死！士林9旬老翁上午打疫苗傍晚身體不適死亡',
# '首例！高鐵站務人員確診媽媽在醫院工作、打過莫德納疫苗仍染全家',
# '畫面曝光｜台中長髮妹開小鴨講電話闖紅燈遭撞翻肚！濺血5傷',
# '獨家｜全台接種11人猝死長輩拒打前必看！醫曝疫苗風險一個關鍵時間',
# 'NHK:
# 東京奧運擬開放觀眾入場
#
# 人數尚待決定',
# '郭台銘凌晨臉書發文曝陳時中承諾協助「必將全力以赴」',
# '懶人包｜撿便宜度疫情好康攏底加',
# '長榮鳳凰酒店掛爐烤鴨、麻辣鍋外帶只要999元',
# '台海和平多次躍上國際舞台一張表帶你掌握那些國家力挺台灣',
# '美軍在台海南北演訓軍事專家蘇紫雲：第7艦隊已將台灣周邊視為任務區',
# '快閃挺醫護、獻手臂國產疫苗讓國民黨內炸鍋藍委建議穩紮穩打勿見獵心喜'

# %%
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']  #聲量分析
colrogroup2 = ['#cd0003','#e60003','#ff0004','#ff1a1d','#ff3436','#ff4d4f','#ff6768','#ff8181','#ff9a9b','#ffb4b4']
keywords = ['疫苗','疫情','血氧機','口罩','AZ',
'莫德納','BNT','嬌生','防疫','輝瑞','外送','獨家','診所']
key_count=[]

for name in keywords:
    count=0
    for mentioned in titles:
        if name in str(mentioned):
            count+=1
    key_count.append(count)

plt.bar(keywords,key_count,color=colrogroup2)
plt.xticks(fontsize=15,rotation=90)
for index,titles in enumerate(key_count):
    plt.text(x=index,y=titles,s=titles,verticalalignment='top',horizontalalignment='center')
plt.xlabel('關鍵字名稱',fontsize=15)
plt.ylabel('聲量',fontsize=15)
plt.title('蘋果新聞關鍵字聲量分析',fontsize=20)
plt.show()

# %%
from snownlp import SnowNLP

# %%
title_ls = [i.strip(",'") for i in text.split('\n')] #把爬下來的標題整理一下
title_ls = [i for i in title_ls if i!='']
title_ls
# Out:
# ['陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑',
#  '高嘉瑜「得寸進尺」內容曝光5度傳訊北市衛生局長為禾馨喬疫苗、還要莫德納',
#  '陳其邁怒了！蚵仔寮魚市湧人潮他只給1天改善：做不到就關門',
#  '友邦巴拉圭預購100萬劑聯亞製造疫苗就等台灣緊急授權',
#  '保單紓困｜比勞工貸優惠！下月起每家保險公司1人1保單可借10萬元',
#  '邱毅赴廈門打疫苗讓中國歡呼盤點這些人都去了',
#  '米砂裙底露餡黑黑的網驚放大照片看！她親自回應了',
#  '還好辣個男人神救援！補教名師：民進黨2022從預料慘敗到出現轉圜',
#  '台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責',
#  '新婚人妻夜奔小王家「玩手遊」夫捉姦驚見滿屋人',
#  '晶片換疫苗全民熱議謝金河：台積電是有威力的！',
#  '傳播妹昏睡遭熟客性侵怒問「為何睡我」！他竟答：又不是第一次',
#  '雨彈來襲！高雄桃源等5區明停班停課疫苗不打了',
#  '勞工紓困貸｜客訴接不完！銀行曝：這2種人線上申辦被打槍機率高',
#  '獨家｜台中今暴增5人打疫苗後死亡盧秀燕說話了',
#  '台中6月爆10起死亡車禍7件是超速！警察今起大執法',
#  '傻眼！百公尺9秒89跑不進奧運美國短跑實力太誇張',
#  '又是冷藏庫！日本再報廢千餘劑新冠肺炎疫苗北海道大阪都出包',
#  '迷姦人妻無恥狡辯「是我被下藥」診所主任判賠129萬坐牢10年',
#  '士林長照48染疫3死給柯Ｐ教訓「打過疫苗還中招、普篩潛伏期傳給一狗票人」',
#  '埔里休旅車冒煙開門赫見一對20歲男女明顯死亡',
#  '全球股市不斷更新｜美股大跌後反攻道瓊早盤大漲逾500點',
#  '指台灣當小弟收疫苗鄭運鵬兩句話酸爆柯文哲高嘉瑜',
#  '再嗆柯文哲甩鍋林右昌：我是真的覺得很不爽！',
#  '不只好心肝！振興醫院找8名「志工」和連戰夫婦分享同瓶疫苗黃珊珊：要查身份',
#  '廣告大亨被小三爆「做愛不戴套」正宮驚收親密照！全因他有了小四',
#  '謝忻因他出一張嘴縫11針腳爆血「啵啵」流！「天團男團員」事不關己',
#  '諷刺！彰化里長妻起壇驅疫4人確診足跡釀7縣市宗教群聚新風暴',
#  '屏東女僅穿內衣倚門比出「1」手勢玩完惹',
#  '病例總整理｜打疫苗84人猝死屏東嬤早上接種疫苗！中午送急診（不斷更新）',
#  '撿便宜懶人包｜五賀拉麵挺醫護人員外帶拉麵品項半價優惠',
#  '時尚｜PRADA春夏滿滿小短褲男李鍾碩、櫻田通在線看秀沒先來1件',
#  '詩人吳岱穎睡夢中辭世享年45歲',
#  '禾馨公布遭「強灌20瓶」關鍵對話衛生局：市長講今一定要打完、不然我們就慘了',
#  '台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責',
#  '《紐時》：美捐台250萬劑疫苗美中關係恐更緊繃',
#  '陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑',
#  '一圖掌握疫苗接種10大順位孕婦即起優先打、任選莫德納或AZ']

# %%
procce_dt = {idx:{'sentence':sent} for idx, sent in enumerate(title_ls)}
procce_dt
# Out:
# {0: {'sentence': '陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑'},
#  1: {'sentence': '高嘉瑜「得寸進尺」內容曝光5度傳訊北市衛生局長為禾馨喬疫苗、還要莫德納'},
#  2: {'sentence': '陳其邁怒了！蚵仔寮魚市湧人潮他只給1天改善：做不到就關門'},
#  3: {'sentence': '友邦巴拉圭預購100萬劑聯亞製造疫苗就等台灣緊急授權'},
#  4: {'sentence': '保單紓困｜比勞工貸優惠！下月起每家保險公司1人1保單可借10萬元'},
#  5: {'sentence': '邱毅赴廈門打疫苗讓中國歡呼盤點這些人都去了'},
#  6: {'sentence': '米砂裙底露餡黑黑的網驚放大照片看！她親自回應了'},
#  7: {'sentence': '還好辣個男人神救援！補教名師：民進黨2022從預料慘敗到出現轉圜'},
#  8: {'sentence': '台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責'},
#  9: {'sentence': '新婚人妻夜奔小王家「玩手遊」夫捉姦驚見滿屋人'},
#  10: {'sentence': '晶片換疫苗全民熱議謝金河：台積電是有威力的！'},
#  11: {'sentence': '傳播妹昏睡遭熟客性侵怒問「為何睡我」！他竟答：又不是第一次'},
#  12: {'sentence': '雨彈來襲！高雄桃源等5區明停班停課疫苗不打了'},
#  13: {'sentence': '勞工紓困貸｜客訴接不完！銀行曝：這2種人線上申辦被打槍機率高'},
#  14: {'sentence': '獨家｜台中今暴增5人打疫苗後死亡盧秀燕說話了'},
#  15: {'sentence': '台中6月爆10起死亡車禍7件是超速！警察今起大執法'},
#  16: {'sentence': '傻眼！百公尺9秒89跑不進奧運美國短跑實力太誇張'},
#  17: {'sentence': '又是冷藏庫！日本再報廢千餘劑新冠肺炎疫苗北海道大阪都出包'},
#  18: {'sentence': '迷姦人妻無恥狡辯「是我被下藥」診所主任判賠129萬坐牢10年'},
#  19: {'sentence': '士林長照48染疫3死給柯Ｐ教訓「打過疫苗還中招、普篩潛伏期傳給一狗票人」'},
#  20: {'sentence': '埔里休旅車冒煙開門赫見一對20歲男女明顯死亡'},
#  21: {'sentence': '全球股市不斷更新｜美股大跌後反攻道瓊早盤大漲逾500點'},
#  22: {'sentence': '指台灣當小弟收疫苗鄭運鵬兩句話酸爆柯文哲高嘉瑜'},
#  23: {'sentence': '再嗆柯文哲甩鍋林右昌：我是真的覺得很不爽！'},
#  24: {'sentence': '不只好心肝！振興醫院找8名「志工」和連戰夫婦分享同瓶疫苗黃珊珊：要查身份'},
#  25: {'sentence': '廣告大亨被小三爆「做愛不戴套」正宮驚收親密照！全因他有了小四'},
#  26: {'sentence': '謝忻因他出一張嘴縫11針腳爆血「啵啵」流！「天團男團員」事不關己'},
#  27: {'sentence': '諷刺！彰化里長妻起壇驅疫4人確診足跡釀7縣市宗教群聚新風暴'},
#  28: {'sentence': '屏東女僅穿內衣倚門比出「1」手勢玩完惹'},
#  29: {'sentence': '病例總整理｜打疫苗84人猝死屏東嬤早上接種疫苗！中午送急診（不斷更新）'},
#  30: {'sentence': '撿便宜懶人包｜五賀拉麵挺醫護人員外帶拉麵品項半價優惠'},
#  31: {'sentence': '時尚｜PRADA春夏滿滿小短褲男李鍾碩、櫻田通在線看秀沒先來1件'},
#  32: {'sentence': '詩人吳岱穎睡夢中辭世享年45歲'},
#  33: {'sentence': '禾馨公布遭「強灌20瓶」關鍵對話衛生局：市長講今一定要打完、不然我們就慘了'},
#  34: {'sentence': '台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責'},
#  35: {'sentence': '《紐時》：美捐台250萬劑疫苗美中關係恐更緊繃'},
#  36: {'sentence': '陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑'},
#  37: {'sentence': '一圖掌握疫苗接種10大順位孕婦即起優先打、任選莫德納或AZ'}}

# %%
for idx, sent_dt in procce_dt.items():
    snow = SnowNLP(sent_dt['sentence'])
    procce_dt[idx]['words'] = snow.words #斷詞
    procce_dt[idx]['tags'] = list(snow.tags) #詞性
    procce_dt[idx]['sentiments'] = snow.sentiments #情感分析
    procce_dt[idx]['pinyin'] = snow.pinyin #拼音
    procce_dt[idx]['keywords'] = snow.keywords(3) #關鍵字
    procce_dt[idx]['summary'] = snow.summary(1) #摘要
    # procce_dt[idx]['tf'] = snow.tf
    # procce_dt[idx]['idf'] = snow.idf

# %%
procce_dt[0]
# Out:
# {'sentence': '陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑',
#  'words': ['陳',
#   '其',
#   '邁',
#   '搶先',
#   '宣布',
#   '！',
#   '高',
#   '雄孕',
#   '婦',
#   '6/23',
#   '起',
#   '打',
#   '莫',
#   '德',
#   '納',
#   '中',
#   '央',
#   '打',
#   '槍',
#   '：',
#   '這',
#   '三',
#   '類',
#   '才',
#   '能',
#   '挑'],
#  'tags': [('陳', 'Ag'),
#   ('其', 'r'),
#   ('邁', 'Ag'),
#   ('搶先', 'Ng'),
#   ('宣布', 'v'),
#   ('！', 'w'),
#   ('高', 'a'),
#   ('雄孕', 'Rg'),
#   ('婦', 'Rg'),
#   ('6/23', 'Rg'),
#   ('起', 'v'),
#   ('打', 'v'),
#   ('莫', 'nr'),
#   ('德', 'nr'),
#   ('納', 'Tg'),
#   ('中', 'v'),
#   ('央', 'Tg'),
#   ('打', 'v'),
#   ('槍', 'Tg'),
#   ('：', 'w'),
#   ('這', 'Tg'),
#   ('三', 'm'),
#   ('類', 'Ng'),
#   ('才', 'd'),
#   ('能', 'v'),
#   ('挑', 'v')],
#  'sentiments': 0.4202805115232833,
#  'pinyin': ['陳',
#   'qi',
#   '邁',
#   '搶',
#   'xian',
#   'xuan',
#   'bu',
#   '！',
#   'gao',
#   'xiong',
#   'yun',
#   '婦',
#   '6/23',
#   'qi',
#   'da',
#   'mo',
#   'de',
#   '納',
#   'zhong',
#   'yang',
#   'da',
#   '槍',
#   '：',
#   '這',
#   'san',
#   '類',
#   'cai',
#   'neng',
#   'tiao'],
#  'keywords': ['這', '莫', '槍'],
#  'summary': ['陳其邁搶先宣布']}

# %%
df1 = pd.DataFrame(procce_dt).T

# %%
df1.head()
# Out:
#                               sentence  \
# 0     陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑
# 1  高嘉瑜「得寸進尺」內容曝光5度傳訊北市衛生局長為禾馨喬疫苗、還要莫德納
# 2         陳其邁怒了！蚵仔寮魚市湧人潮他只給1天改善：做不到就關門
# 3           友邦巴拉圭預購100萬劑聯亞製造疫苗就等台灣緊急授權
# 4     保單紓困｜比勞工貸優惠！下月起每家保險公司1人1保單可借10萬元
#
#                                                words  \
# 0  [陳, 其, 邁, 搶先, 宣布, ！, 高, 雄孕, 婦, 6/23, 起, 打, 莫, ...
# 1  [高, 嘉瑜, 「, 得寸, 進尺, 」, 內容, 曝光, 5, 度, 傳, 訊, 北, 市...
# 2  [陳, 其, 邁怒, 了, ！, 蚵, 仔, 寮, 魚, 市, 湧, 人, 潮, 他, 只,...
# 3  [友邦, 巴, 拉, 圭, 預, 購, 100, 萬, 劑, 聯, 亞, 製造, 疫苗, 就...
# 4  [保, 單, 紓, 困, ｜, 比, 勞, 工, 貸, 優惠, ！, 下月, 起, 每, 家...
#
#                                                 tags sentiments  \
# 0  [(陳, Ag), (其, r), (邁, Ag), (搶先, Ng), (宣布, v), ...   0.420281
# 1  [(高, a), (嘉瑜, o), (「, o), (得寸, o), (進尺, o), (」...   0.041103
# 2  [(陳, Ag), (其, r), (邁怒, Ag), (了, y), (！, w), (蚵...   0.023451
# 3  [(友邦, n), (巴, j), (拉, v), (圭, o), (預, o), (購, ...   0.588271
# 4  [(保, nr), (單, Dg), (紓, Vg), (困, an), (｜, Tg), ...   0.293131
#
#                                               pinyin     keywords  \
# 0  [陳, qi, 邁, 搶, xian, xuan, bu, ！, gao, xiong, y...    [這, 莫, 槍]
# 1  [gao, 嘉, 瑜, 「, de, cun, 進, chi, 」, 內, rong, ba...  [進尺, 疫苗, 喬]
# 2  [陳, qi, 邁, nu, liao, ！, 蚵, 仔, 寮, 魚, shi, 湧, re...   [改善, 市, 天]
# 3  [you, bang, ba, la, 圭, 預, 購, 100, 萬, 劑, 聯, 亞, ...    [台, 預, 購]
# 4  [bao, 單, 紓, kun, ｜, bi, 勞, gong, 貸, 優, hui, ！,...    [保, 單, ｜]
#
#                                  summary
# 0                              [陳其邁搶先宣布]
# 1  [高嘉瑜「得寸進尺」內容曝光5度傳訊北市衛生局長為禾馨喬疫苗、還要莫德納]
# 2                                [陳其邁怒了]
# 3           [友邦巴拉圭預購100萬劑聯亞製造疫苗就等台灣緊急授權]
# 4                          [保單紓困｜比勞工貸優惠]

# %%
import jieba #用另一個語料庫再跑一次

# %%
procce_dt = {idx:{'sentence':sent, 'words': list(jieba.cut(sent, cut_all=False))} for idx, sent in enumerate(title_ls)}
procce_dt
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\aaron\AppData\Local\Temp\jieba.cache
# Loading model cost 0.822 seconds.
# Prefix dict has been built successfully.
# {0: {'sentence': '陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑',
#   'words': ['陳',
#    '其邁',
#    '搶',
#    '先',
#    '宣布',
#    '！',
#    '高雄',
#    '孕婦',
#    '6',
#    '/',
#    '23',
#    '起',
#    '打莫德納',
#    '中央',
#    '打槍',
#    '：',
#    '這三類',
#    '才能',
#    '挑']},
#  1: {'sentence': '高嘉瑜「得寸進尺」內容曝光5度傳訊北市衛生局長為禾馨喬疫苗、還要莫德納',
#   'words': ['高嘉瑜',
#    '「',
#    '得寸',
#    '進尺',
#    '」',
#    '內容',
#    '曝光',
#    '5',
#    '度',
#    '傳訊北市',
#    '衛生',
#    '局長',
#    '為',
#    '禾',
#    '馨',
#    '喬',
#    '疫苗',
#    '、',
#    '還要',
#    '莫德納']},
#  2: {'sentence': '陳其邁怒了！蚵仔寮魚市湧人潮他只給1天改善：做不到就關門',
#   'words': ['陳',
#    '其',
#    '邁怒',
#    '了',
#    '！',
#    '蚵',
#    '仔',
#    '寮',
#    '魚市',
#    '湧',
#    '人潮',
#    '他',
#    '只給',
#    '1',
#    '天',
#    '改善',
#    '：',
#    '做',
#    '不到',
#    '就',
#    '關門']},
#  3: {'sentence': '友邦巴拉圭預購100萬劑聯亞製造疫苗就等台灣緊急授權',
#   'words': ['友邦',
#    '巴拉圭',
#    '預購',
#    '100',
#    '萬劑',
#    '聯',
#    '亞',
#    '製',
#    '造',
#    '疫苗',
#    '就',
#    '等',
#    '台灣',
#    '緊急',
#    '授權']},
#  4: {'sentence': '保單紓困｜比勞工貸優惠！下月起每家保險公司1人1保單可借10萬元',
#   'words': ['保單',
#    '紓',
#    '困',
#    '｜',
#    '比勞',
#    '工貸',
#    '優惠',
#    '！',
#    '下',
#    '月',
#    '起',
#    '每家',
#    '保險',
#    '公司',
#    '1',
#    '人',
#    '1',
#    '保單',
#    '可',
#    '借',
#    '10',
#    '萬元']},
#  5: {'sentence': '邱毅赴廈門打疫苗讓中國歡呼盤點這些人都去了',
#   'words': ['邱毅',
#    '赴',
#    '廈門',
#    '打',
#    '疫苗',
#    '讓',
#    '中國歡',
#    '呼盤點',
#    '這些',
#    '人',
#    '都',
#    '去',
#    '了']},
#  6: {'sentence': '米砂裙底露餡黑黑的網驚放大照片看！她親自回應了',
#   'words': ['米',
#    '砂裙',
#    '底露',
#    '餡',
#    '黑黑的',
#    '網驚',
#    '放大',
#    '照片',
#    '看',
#    '！',
#    '她',
#    '親自',
#    '回應',
#    '了']},
#  7: {'sentence': '還好辣個男人神救援！補教名師：民進黨2022從預料慘敗到出現轉圜',
#   'words': ['還好',
#    '辣個',
#    '男人',
#    '神',
#    '救援',
#    '！',
#    '補教',
#    '名師',
#    '：',
#    '民進',
#    '黨',
#    '2022',
#    '從',
#    '預料',
#    '慘敗',
#    '到',
#    '出',
#    '現轉',
#    '圜']},
#  8: {'sentence': '台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責',
#   'words': ['台南',
#    '檢察長',
#    '爆特權',
#    '偷打',
#    '疫苗',
#    '檢察官',
#    '怒控',
#    '貪污',
#    '！',
#    '黃',
#    '國昌籲',
#    '部長',
#    '總長',
#    '速究責']},
#  9: {'sentence': '新婚人妻夜奔小王家「玩手遊」夫捉姦驚見滿屋人',
#   'words': ['新婚',
#    '人',
#    '妻夜',
#    '奔',
#    '小',
#    '王家',
#    '「',
#    '玩手',
#    '遊',
#    '」',
#    '夫捉姦',
#    '驚見',
#    '滿屋',
#    '人']},
#  10: {'sentence': '晶片換疫苗全民熱議謝金河：台積電是有威力的！',
#   'words': ['晶片',
#    '換',
#    '疫苗',
#    '全民',
#    '熱議',
#    '謝',
#    '金河',
#    '：',
#    '台積',
#    '電是',
#    '有',
#    '威力',
#    '的',
#    '！']},
#  11: {'sentence': '傳播妹昏睡遭熟客性侵怒問「為何睡我」！他竟答：又不是第一次',
#   'words': ['傳播妹',
#    '昏睡',
#    '遭',
#    '熟客',
#    '性侵',
#    '怒問',
#    '「',
#    '為何',
#    '睡',
#    '我',
#    '」',
#    '！',
#    '他',
#    '竟答',
#    '：',
#    '又',
#    '不是',
#    '第一次']},
#  12: {'sentence': '雨彈來襲！高雄桃源等5區明停班停課疫苗不打了',
#   'words': ['雨彈',
#    '來襲',
#    '！',
#    '高雄',
#    '桃源',
#    '等',
#    '5',
#    '區明',
#    '停班',
#    '停課',
#    '疫苗',
#    '不',
#    '打',
#    '了']},
#  13: {'sentence': '勞工紓困貸｜客訴接不完！銀行曝：這2種人線上申辦被打槍機率高',
#   'words': ['勞工',
#    '紓',
#    '困貸',
#    '｜',
#    '客訴',
#    '接不完',
#    '！',
#    '銀行',
#    '曝',
#    '：',
#    '這',
#    '2',
#    '種人線',
#    '上',
#    '申辦',
#    '被',
#    '打槍',
#    '機率',
#    '高']},
#  14: {'sentence': '獨家｜台中今暴增5人打疫苗後死亡盧秀燕說話了',
#   'words': ['獨家',
#    '｜',
#    '台中',
#    '今',
#    '暴增',
#    '5',
#    '人',
#    '打',
#    '疫苗',
#    '後',
#    '死亡',
#    '盧秀燕',
#    '說',
#    '話',
#    '了']},
#  15: {'sentence': '台中6月爆10起死亡車禍7件是超速！警察今起大執法',
#   'words': ['台中',
#    '6',
#    '月',
#    '爆',
#    '10',
#    '起',
#    '死亡',
#    '車禍',
#    '7',
#    '件',
#    '是',
#    '超速',
#    '！',
#    '警察',
#    '今起',
#    '大',
#    '執法']},
#  16: {'sentence': '傻眼！百公尺9秒89跑不進奧運美國短跑實力太誇張',
#   'words': ['傻眼',
#    '！',
#    '百',
#    '公尺',
#    '9',
#    '秒',
#    '89',
#    '跑',
#    '不進',
#    '奧運美國',
#    '短跑',
#    '實力',
#    '太',
#    '誇張']},
#  17: {'sentence': '又是冷藏庫！日本再報廢千餘劑新冠肺炎疫苗北海道大阪都出包',
#   'words': ['又',
#    '是',
#    '冷藏',
#    '庫',
#    '！',
#    '日本',
#    '再報',
#    '廢千餘劑',
#    '新冠',
#    '肺炎',
#    '疫苗',
#    '北海道',
#    '大阪',
#    '都',
#    '出包']},
#  18: {'sentence': '迷姦人妻無恥狡辯「是我被下藥」診所主任判賠129萬坐牢10年',
#   'words': ['迷姦',
#    '人',
#    '妻無恥',
#    '狡辯',
#    '「',
#    '是',
#    '我',
#    '被',
#    '下藥',
#    '」',
#    '診所',
#    '主任',
#    '判賠',
#    '129',
#    '萬',
#    '坐牢',
#    '10',
#    '年']},
#  19: {'sentence': '士林長照48染疫3死給柯Ｐ教訓「打過疫苗還中招、普篩潛伏期傳給一狗票人」',
#   'words': ['士林',
#    '長',
#    '照',
#    '48',
#    '染疫',
#    '3',
#    '死給',
#    '柯',
#    'Ｐ',
#    '教訓',
#    '「',
#    '打過',
#    '疫苗',
#    '還',
#    '中招',
#    '、',
#    '普篩',
#    '潛伏期',
#    '傳給',
#    '一狗票',
#    '人',
#    '」']},
#  20: {'sentence': '埔里休旅車冒煙開門赫見一對20歲男女明顯死亡',
#   'words': ['埔里',
#    '休旅車',
#    '冒',
#    '煙',
#    '開門',
#    '赫見',
#    '一',
#    '對',
#    '20',
#    '歲',
#    '男女',
#    '明顯',
#    '死亡']},
#  21: {'sentence': '全球股市不斷更新｜美股大跌後反攻道瓊早盤大漲逾500點',
#   'words': ['全球股市',
#    '不斷',
#    '更新',
#    '｜',
#    '美股',
#    '大跌',
#    '後',
#    '反攻',
#    '道瓊',
#    '早盤',
#    '大漲',
#    '逾',
#    '500',
#    '點']},
#  22: {'sentence': '指台灣當小弟收疫苗鄭運鵬兩句話酸爆柯文哲高嘉瑜',
#   'words': ['指台灣當',
#    '小弟',
#    '收',
#    '疫苗',
#    '鄭運鵬',
#    '兩句',
#    '話',
#    '酸',
#    '爆',
#    '柯文',
#    '哲高嘉瑜']},
#  23: {'sentence': '再嗆柯文哲甩鍋林右昌：我是真的覺得很不爽！',
#   'words': ['再',
#    '嗆',
#    '柯文',
#    '哲',
#    '甩',
#    '鍋林',
#    '右昌',
#    '：',
#    '我',
#    '是',
#    '真的',
#    '覺得',
#    '很',
#    '不爽',
#    '！']},
#  24: {'sentence': '不只好心肝！振興醫院找8名「志工」和連戰夫婦分享同瓶疫苗黃珊珊：要查身份',
#   'words': ['不',
#    '只好',
#    '心肝',
#    '！',
#    '振興',
#    '醫院',
#    '找',
#    '8',
#    '名',
#    '「',
#    '志工',
#    '」',
#    '和',
#    '連戰夫婦',
#    '分享',
#    '同瓶',
#    '疫苗',
#    '黃',
#    '珊',
#    '珊',
#    '：',
#    '要查',
#    '身份']},
#  25: {'sentence': '廣告大亨被小三爆「做愛不戴套」正宮驚收親密照！全因他有了小四',
#   'words': ['廣告',
#    '大亨',
#    '被',
#    '小三爆',
#    '「',
#    '做',
#    '愛不戴套',
#    '」',
#    '正宮',
#    '驚',
#    '收親',
#    '密照',
#    '！',
#    '全因',
#    '他',
#    '有',
#    '了',
#    '小',
#    '四']},
#  26: {'sentence': '謝忻因他出一張嘴縫11針腳爆血「啵啵」流！「天團男團員」事不關己',
#   'words': ['謝忻因',
#    '他',
#    '出',
#    '一張',
#    '嘴縫',
#    '11',
#    '針腳',
#    '爆血',
#    '「',
#    '啵',
#    '啵',
#    '」',
#    '流',
#    '！',
#    '「',
#    '天團',
#    '男團員',
#    '」',
#    '事',
#    '不',
#    '關己']},
#  27: {'sentence': '諷刺！彰化里長妻起壇驅疫4人確診足跡釀7縣市宗教群聚新風暴',
#   'words': ['諷刺',
#    '！',
#    '彰化',
#    '里長',
#    '妻起壇',
#    '驅疫',
#    '4',
#    '人確',
#    '診足跡',
#    '釀',
#    '7',
#    '縣市',
#    '宗教',
#    '群聚',
#    '新風暴']},
#  28: {'sentence': '屏東女僅穿內衣倚門比出「1」手勢玩完惹',
#   'words': ['屏東',
#    '女僅',
#    '穿',
#    '內衣',
#    '倚門',
#    '比出',
#    '「',
#    '1',
#    '」',
#    '手勢',
#    '玩完',
#    '惹']},
#  29: {'sentence': '病例總整理｜打疫苗84人猝死屏東嬤早上接種疫苗！中午送急診（不斷更新）',
#   'words': ['病例',
#    '總',
#    '整理',
#    '｜',
#    '打',
#    '疫苗',
#    '84',
#    '人',
#    '猝死',
#    '屏東',
#    '嬤',
#    '早上',
#    '接種',
#    '疫苗',
#    '！',
#    '中午',
#    '送急診',
#    '（',
#    '不斷',
#    '更新',
#    '）']},
#  30: {'sentence': '撿便宜懶人包｜五賀拉麵挺醫護人員外帶拉麵品項半價優惠',
#   'words': ['撿',
#    '便宜',
#    '懶人包',
#    '｜',
#    '五賀',
#    '拉',
#    '麵',
#    '挺',
#    '醫護',
#    '人員外',
#    '帶',
#    '拉',
#    '麵',
#    '品項',
#    '半價',
#    '優惠']},
#  31: {'sentence': '時尚｜PRADA春夏滿滿小短褲男李鍾碩、櫻田通在線看秀沒先來1件',
#   'words': ['時尚',
#    '｜',
#    'PRADA',
#    '春夏',
#    '滿滿',
#    '小',
#    '短褲',
#    '男',
#    '李鍾碩',
#    '、',
#    '櫻田通',
#    '在',
#    '線',
#    '看秀',
#    '沒先來',
#    '1',
#    '件']},
#  32: {'sentence': '詩人吳岱穎睡夢中辭世享年45歲',
#   'words': ['詩人', '吳岱穎', '睡夢中', '辭世', '享年', '45', '歲']},
#  33: {'sentence': '禾馨公布遭「強灌20瓶」關鍵對話衛生局：市長講今一定要打完、不然我們就慘了',
#   'words': ['禾馨',
#    '公布',
#    '遭',
#    '「',
#    '強灌',
#    '20',
#    '瓶',
#    '」',
#    '關鍵',
#    '對',
#    '話',
#    '衛生局',
#    '：',
#    '市長',
#    '講今',
#    '一定',
#    '要',
#    '打',
#    '完',
#    '、',
#    '不然',
#    '我們',
#    '就',
#    '慘了']},
#  34: {'sentence': '台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責',
#   'words': ['台南',
#    '檢察長',
#    '爆特權',
#    '偷打',
#    '疫苗',
#    '檢察官',
#    '怒控',
#    '貪污',
#    '！',
#    '黃',
#    '國昌籲',
#    '部長',
#    '總長',
#    '速究責']},
#  35: {'sentence': '《紐時》：美捐台250萬劑疫苗美中關係恐更緊繃',
#   'words': ['《',
#    '紐時',
#    '》',
#    '：',
#    '美捐台',
#    '250',
#    '萬劑',
#    '疫苗',
#    '美中關',
#    '係',
#    '恐',
#    '更',
#    '緊',
#    '繃']},
#  36: {'sentence': '陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑',
#   'words': ['陳',
#    '其邁',
#    '搶',
#    '先',
#    '宣布',
#    '！',
#    '高雄',
#    '孕婦',
#    '6',
#    '/',
#    '23',
#    '起',
#    '打莫德納',
#    '中央',
#    '打槍',
#    '：',
#    '這三類',
#    '才能',
#    '挑']},
#  37: {'sentence': '一圖掌握疫苗接種10大順位孕婦即起優先打、任選莫德納或AZ',
#   'words': ['一圖',
#    '掌握',
#    '疫苗',
#    '接種',
#    '10',
#    '大順位',
#    '孕婦',
#    '即',
#    '起',
#    '優先',
#    '打',
#    '、',
#    '任選',
#    '莫德納',
#    '或',
#    'AZ']}}

# %%
for idx, sent_dt in procce_dt.items():
    snow = SnowNLP(' '.join(procce_dt[idx]['words']))
    procce_dt[idx]['tags'] = list(snow.tags) 
    procce_dt[idx]['sentiments'] = snow.sentiments
    procce_dt[idx]['pinyin'] = snow.pinyin # 
    procce_dt[idx]['keywords'] = snow.keywords(3)
    procce_dt[idx]['summary'] = snow.summary(1)
    # procce_dt[idx]['tf'] = snow.tf
    # procce_dt[idx]['idf'] = snow.idf

# %%
procce_dt[0]
# Out:
# {'sentence': '陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑',
#  'words': ['陳',
#   '其邁',
#   '搶',
#   '先',
#   '宣布',
#   '！',
#   '高雄',
#   '孕婦',
#   '6',
#   '/',
#   '23',
#   '起',
#   '打莫德納',
#   '中央',
#   '打槍',
#   '：',
#   '這三類',
#   '才能',
#   '挑'],
#  'tags': [('陳', 'p'),
#   ('其', 'r'),
#   ('邁', 'Rg'),
#   ('搶', 'Rg'),
#   ('先', 'd'),
#   ('宣布', 'v'),
#   ('！', 'w'),
#   ('高雄', 'ns'),
#   ('孕', 'o'),
#   ('婦', 'o'),
#   ('6', 'o'),
#   ('/', 'e'),
#   ('23', 'e'),
#   ('起', 'v'),
#   ('打', 'v'),
#   ('莫', 'd'),
#   ('德', 'j'),
#   ('納', 'j'),
#   ('中央', 'n'),
#   ('打', 'v'),
#   ('槍', 'nx'),
#   ('：', 'w'),
#   ('這', 'nx'),
#   ('三', 'm'),
#   ('類', 'nx'),
#   ('才', 'd'),
#   ('能', 'v'),
#   ('挑', 'v')],
#  'sentiments': 0.022093490669646054,
#  'pinyin': ['陳',
#   'qi',
#   '邁',
#   '搶',
#   'xian',
#   'xuan',
#   'bu',
#   '！',
#   'gao',
#   'xiong',
#   'yun',
#   '婦',
#   '6',
#   '/',
#   '23',
#   'qi',
#   'da',
#   'mo',
#   'de',
#   '納',
#   'zhong',
#   'yang',
#   'da',
#   '槍',
#   '：',
#   '這',
#   'san',
#   '類',
#   'cai',
#   'neng',
#   'tiao'],
#  'keywords': ['23', '這', '槍'],
#  'summary': ['陳 其邁 搶 先 宣布']}

# %%
df2 = pd.DataFrame(procce_dt).T

# %%
df2
# Out:
#                                  sentence  \
# 0        陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑
# 1     高嘉瑜「得寸進尺」內容曝光5度傳訊北市衛生局長為禾馨喬疫苗、還要莫德納
# 2            陳其邁怒了！蚵仔寮魚市湧人潮他只給1天改善：做不到就關門
# 3              友邦巴拉圭預購100萬劑聯亞製造疫苗就等台灣緊急授權
# 4        保單紓困｜比勞工貸優惠！下月起每家保險公司1人1保單可借10萬元
# 5                   邱毅赴廈門打疫苗讓中國歡呼盤點這些人都去了
# 6                 米砂裙底露餡黑黑的網驚放大照片看！她親自回應了
# 7        還好辣個男人神救援！補教名師：民進黨2022從預料慘敗到出現轉圜
# 8         台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責
# 9                  新婚人妻夜奔小王家「玩手遊」夫捉姦驚見滿屋人
# 10                 晶片換疫苗全民熱議謝金河：台積電是有威力的！
# 11          傳播妹昏睡遭熟客性侵怒問「為何睡我」！他竟答：又不是第一次
# 12                 雨彈來襲！高雄桃源等5區明停班停課疫苗不打了
# 13         勞工紓困貸｜客訴接不完！銀行曝：這2種人線上申辦被打槍機率高
# 14                 獨家｜台中今暴增5人打疫苗後死亡盧秀燕說話了
# 15              台中6月爆10起死亡車禍7件是超速！警察今起大執法
# 16               傻眼！百公尺9秒89跑不進奧運美國短跑實力太誇張
# 17           又是冷藏庫！日本再報廢千餘劑新冠肺炎疫苗北海道大阪都出包
# 18         迷姦人妻無恥狡辯「是我被下藥」診所主任判賠129萬坐牢10年
# 19   士林長照48染疫3死給柯Ｐ教訓「打過疫苗還中招、普篩潛伏期傳給一狗票人」
# 20                 埔里休旅車冒煙開門赫見一對20歲男女明顯死亡
# 21            全球股市不斷更新｜美股大跌後反攻道瓊早盤大漲逾500點
# 22                指台灣當小弟收疫苗鄭運鵬兩句話酸爆柯文哲高嘉瑜
# 23                  再嗆柯文哲甩鍋林右昌：我是真的覺得很不爽！
# 24   不只好心肝！振興醫院找8名「志工」和連戰夫婦分享同瓶疫苗黃珊珊：要查身份
# 25         廣告大亨被小三爆「做愛不戴套」正宮驚收親密照！全因他有了小四
# 26       謝忻因他出一張嘴縫11針腳爆血「啵啵」流！「天團男團員」事不關己
# 27          諷刺！彰化里長妻起壇驅疫4人確診足跡釀7縣市宗教群聚新風暴
# 28                    屏東女僅穿內衣倚門比出「1」手勢玩完惹
# 29    病例總整理｜打疫苗84人猝死屏東嬤早上接種疫苗！中午送急診（不斷更新）
# 30             撿便宜懶人包｜五賀拉麵挺醫護人員外帶拉麵品項半價優惠
# 31       時尚｜PRADA春夏滿滿小短褲男李鍾碩、櫻田通在線看秀沒先來1件
# 32                        詩人吳岱穎睡夢中辭世享年45歲
# 33  禾馨公布遭「強灌20瓶」關鍵對話衛生局：市長講今一定要打完、不然我們就慘了
# 34        台南檢察長爆特權偷打疫苗檢察官怒控貪污！黃國昌籲部長總長速究責
# 35                《紐時》：美捐台250萬劑疫苗美中關係恐更緊繃
# 36       陳其邁搶先宣布！高雄孕婦6/23起打莫德納中央打槍：這三類才能挑
# 37          一圖掌握疫苗接種10大順位孕婦即起優先打、任選莫德納或AZ
#
#                                                 words  \
# 0   [陳, 其邁, 搶, 先, 宣布, ！, 高雄, 孕婦, 6, /, 23, 起, 打莫德納...
# 1   [高嘉瑜, 「, 得寸, 進尺, 」, 內容, 曝光, 5, 度, 傳訊北市, 衛生, 局長...
# 2   [陳, 其, 邁怒, 了, ！, 蚵, 仔, 寮, 魚市, 湧, 人潮, 他, 只給, 1,...
# 3   [友邦, 巴拉圭, 預購, 100, 萬劑, 聯, 亞, 製, 造, 疫苗, 就, 等, 台...
# 4   [保單, 紓, 困, ｜, 比勞, 工貸, 優惠, ！, 下, 月, 起, 每家, 保險, ...
# 5     [邱毅, 赴, 廈門, 打, 疫苗, 讓, 中國歡, 呼盤點, 這些, 人, 都, 去, 了]
# 6   [米, 砂裙, 底露, 餡, 黑黑的, 網驚, 放大, 照片, 看, ！, 她, 親自, 回...
# 7   [還好, 辣個, 男人, 神, 救援, ！, 補教, 名師, ：, 民進, 黨, 2022,...
# 8   [台南, 檢察長, 爆特權, 偷打, 疫苗, 檢察官, 怒控, 貪污, ！, 黃, 國昌籲,...
# 9   [新婚, 人, 妻夜, 奔, 小, 王家, 「, 玩手, 遊, 」, 夫捉姦, 驚見, 滿屋...
# 10  [晶片, 換, 疫苗, 全民, 熱議, 謝, 金河, ：, 台積, 電是, 有, 威力, 的...
# 11  [傳播妹, 昏睡, 遭, 熟客, 性侵, 怒問, 「, 為何, 睡, 我, 」, ！, 他,...
# 12  [雨彈, 來襲, ！, 高雄, 桃源, 等, 5, 區明, 停班, 停課, 疫苗, 不, 打...
# 13  [勞工, 紓, 困貸, ｜, 客訴, 接不完, ！, 銀行, 曝, ：, 這, 2, 種人線...
# 14  [獨家, ｜, 台中, 今, 暴增, 5, 人, 打, 疫苗, 後, 死亡, 盧秀燕, 說,...
# 15  [台中, 6, 月, 爆, 10, 起, 死亡, 車禍, 7, 件, 是, 超速, ！, 警...
# 16  [傻眼, ！, 百, 公尺, 9, 秒, 89, 跑, 不進, 奧運美國, 短跑, 實力, ...
# 17  [又, 是, 冷藏, 庫, ！, 日本, 再報, 廢千餘劑, 新冠, 肺炎, 疫苗, 北海道...
# 18  [迷姦, 人, 妻無恥, 狡辯, 「, 是, 我, 被, 下藥, 」, 診所, 主任, 判賠...
# 19  [士林, 長, 照, 48, 染疫, 3, 死給, 柯, Ｐ, 教訓, 「, 打過, 疫苗,...
# 20   [埔里, 休旅車, 冒, 煙, 開門, 赫見, 一, 對, 20, 歲, 男女, 明顯, 死亡]
# 21  [全球股市, 不斷, 更新, ｜, 美股, 大跌, 後, 反攻, 道瓊, 早盤, 大漲, 逾...
# 22      [指台灣當, 小弟, 收, 疫苗, 鄭運鵬, 兩句, 話, 酸, 爆, 柯文, 哲高嘉瑜]
# 23  [再, 嗆, 柯文, 哲, 甩, 鍋林, 右昌, ：, 我, 是, 真的, 覺得, 很, 不...
# 24  [不, 只好, 心肝, ！, 振興, 醫院, 找, 8, 名, 「, 志工, 」, 和, 連...
# 25  [廣告, 大亨, 被, 小三爆, 「, 做, 愛不戴套, 」, 正宮, 驚, 收親, 密照,...
# 26  [謝忻因, 他, 出, 一張, 嘴縫, 11, 針腳, 爆血, 「, 啵, 啵, 」, 流,...
# 27  [諷刺, ！, 彰化, 里長, 妻起壇, 驅疫, 4, 人確, 診足跡, 釀, 7, 縣市,...
# 28        [屏東, 女僅, 穿, 內衣, 倚門, 比出, 「, 1, 」, 手勢, 玩完, 惹]
# 29  [病例, 總, 整理, ｜, 打, 疫苗, 84, 人, 猝死, 屏東, 嬤, 早上, 接種...
# 30  [撿, 便宜, 懶人包, ｜, 五賀, 拉, 麵, 挺, 醫護, 人員外, 帶, 拉, 麵,...
# 31  [時尚, ｜, PRADA, 春夏, 滿滿, 小, 短褲, 男, 李鍾碩, 、, 櫻田通, ...
# 32                      [詩人, 吳岱穎, 睡夢中, 辭世, 享年, 45, 歲]
# 33  [禾馨, 公布, 遭, 「, 強灌, 20, 瓶, 」, 關鍵, 對, 話, 衛生局, ：,...
# 34  [台南, 檢察長, 爆特權, 偷打, 疫苗, 檢察官, 怒控, 貪污, ！, 黃, 國昌籲,...
# 35  [《, 紐時, 》, ：, 美捐台, 250, 萬劑, 疫苗, 美中關, 係, 恐, 更, ...
# 36  [陳, 其邁, 搶, 先, 宣布, ！, 高雄, 孕婦, 6, /, 23, 起, 打莫德納...
# 37  [一圖, 掌握, 疫苗, 接種, 10, 大順位, 孕婦, 即, 起, 優先, 打, 、, ...
#
#                                                  tags sentiments  \
# 0   [(陳, p), (其, r), (邁, Rg), (搶, Rg), (先, d), (宣布...   0.022093
# 1   [(高, a), (嘉瑜, o), (「, o), (得寸, o), (進尺, o), (」...   0.036512
# 2   [(陳, Ag), (其, r), (邁, Ag), (怒, Bg), (了, u), (！...   0.011983
# 3   [(友邦, n), (巴拉圭, o), (預, o), (購, o), (100, o), ...   0.279647
# 4   [(保, nr), (單, Dg), (紓, Vg), (困, an), (｜, Tg), ...   0.032729
# 5   [(邱, nr), (毅, nr), (赴, v), (廈, Rg), (門, k), (打...   0.509091
# 6   [(米, q), (砂, n), (裙, Ng), (底, f), (露, v), (餡, ...   0.449633
# 7   [(還, Bg), (好, a), (辣, a), (個, u), (男人, n), (神,...   0.900624
# 8   [(台, j), (南, j), (檢察, j), (長, vd), (爆, v), (特,...   0.075464
# 9   [(新婚, n), (人, n), (妻夜, Dg), (奔, v), (小, a), (王...   0.057502
# 10  [(晶片, e), (換, e), (疫苗, n), (全民, n), (熱, Rg), (...   0.876921
# 11  [(傳播, i), (妹, n), (昏, Tg), (睡, v), (遭, v), (熟,...   0.000109
# 12  [(雨, n), (彈, o), (來, e), (襲, e), (！, w), (高雄, ...   0.920977
# 13  [(勞, r), (工, Ng), (紓, Dg), (困, v), (貸, Dg), (｜...   0.051474
# 14  [(獨家, e), (｜, e), (台, q), (中, f), (今, Tg), (暴,...   0.723035
# 15  [(台, j), (中, j), (6, b), (月, n), (爆, v), (10, ...   0.178123
# 16  [(傻, a), (眼, n), (！, w), (百, m), (公尺, q), (9, ...    0.55618
# 17  [(又, d), (是, v), (冷藏, vn), (庫, f), (！, w), (日本...   0.772633
# 18  [(迷, v), (姦, j), (人, n), (妻, Ng), (無, o), (恥, ...   0.046239
# 19  [(士, nr), (林, nr), (長, Tg), (照, v), (48, Tg), ...   0.047188
# 20  [(埔里, Tg), (休, v), (旅, Vg), (車, Ng), (冒, v), (...   0.049223
# 21  [(全球, n), (股市, n), (不, d), (斷, Dg), (更新, v), (...   0.017296
# 22  [(指, v), (台, q), (灣, Ag), (當, Bg), (小, a), (弟,...   0.006829
# 23  [(再, d), (嗆, Vg), (柯, nr), (文, Ng), (哲, Dg), (...    0.02719
# 24  [(不, d), (只好, d), (心, n), (肝, z), (！, w), (振, ...   0.084369
# 25  [(廣告, Dg), (大, a), (亨, nr), (被, p), (小三, Tg), ...   0.927926
# 26  [(謝, e), (忻, e), (因, p), (他, r), (出, v), (一, m...   0.005189
# 27  [(諷, Dg), (刺, v), (！, w), (彰, nr), (化, v), (里,...   0.196478
# 28  [(屏, Rg), (東, Rg), (女, Ng), (僅, Dg), (穿, v), (...   0.753356
# 29  [(病例, n), (總, Dg), (整理, v), (｜, Dg), (打, v), (...   0.260666
# 30  [(撿, Mg), (便宜, a), (懶, Ag), (人, n), (包, v), (｜...   0.656102
# 31  [(時, nr), (尚, nr), (｜, o), (PRADA, o), (春夏, o)...   0.005507
# 32  [(詩, ns), (人, n), (吳岱, Rg), (穎, Rg), (睡, v), (...   0.377621
# 33  [(禾, Ng), (馨, Ng), (公布, v), (遭, v), (「, Rg), (...    0.03088
# 34  [(台, j), (南, j), (檢察, j), (長, vd), (爆, v), (特,...   0.075464
# 35  [(《, w), (紐, e), (時, e), (》, w), (：, w), (美, j...   0.997397
# 36  [(陳, p), (其, r), (邁, Rg), (搶, Rg), (先, d), (宣布...   0.022093
# 37  [(一, m), (圖, q), (掌握, v), (疫苗, n), (接, v), (種,...   0.138961
#
#                                                pinyin      keywords  \
# 0   [陳, qi, 邁, 搶, xian, xuan, bu, ！, gao, xiong, y...    [23, 這, 槍]
# 1   [gao, 嘉, 瑜, 「, de, cun, 進, chi, 」, 內, rong, ba...   [疫苗, 進尺, 」]
# 2   [陳, qi, 邁, nu, liao, ！, 蚵, 仔, 寮, 魚, shi, 湧, re...    [改善, 市, 天]
# 3   [you, bang, ba, la, 圭, 預, 購, 100, 萬, 劑, 聯, 亞, ...   [台, 100, 萬]
# 4   [bao, 單, 紓, kun, ｜, bi, 勞, gong, 貸, 優, hui, ！,...     [保, 單, ｜]
# 5   [邱, 毅, fu, 廈, 門, da, yi, miao, 讓, zhong, 國, 歡,...    [點, 門, 疫苗]
# 6   [mi, sha, 裙, di, lu, 餡, hei, hei, de, 網, 驚, fa...     [露, 網, 餡]
# 7   [還, hao, la, 個, nan, ren, shen, jiu, yuan, ！, ...     [民, 敗, 個]
# 8   [tai, nan, 檢, cha, 長, bao, te, 權, tou, da, yi,...   [長, 爆, 檢察官]
# 9   [xin, hun, ren, qi, ye, ben, xiao, wang, jia, ...     [人, 小, 姦]
# 10  [jing, pian, 換, yi, miao, quan, min, 熱, 議, 謝, ...    [熱, 金河, 謝]
# 11  [傳, bo, mei, hun, shui, zao, shu, ke, xing, 侵,...     [睡, 遭, 問]
# 12  [yu, 彈, 來, 襲, ！, gao, xiong, tao, yuan, deng, ...   [區明, 停班, 停]
# 13  [勞, gong, 紓, kun, 貸, ｜, ke, 訴, jie, bu, wan, ！...     [客, 貸, ｜]
# 14  [獨, jia, ｜, tai, zhong, jin, bao, zeng, 5, ren...    [今, 死亡, 後]
# 15  [tai, zhong, 6, yue, bao, 10, qi, si, wang, 車,...    [爆, 車, 死亡]
# 16  [sha, yan, ！, bai, gong, chi, 9, miao, 89, pao...    [跑, 89, 短]
# 17  [you, shi, leng, cang, 庫, ！, ri, ben, zai, 報, ...  [千, 北海道, 疫苗]
# 18  [mi, 姦, ren, qi, 無, 恥, 狡, 辯, 「, shi, wo, bei, ...   [129, 無, 恥]
# 19  [shi, lin, 長, zhao, 48, ran, 疫, 3, si, 給, ke, ...    [給, 染疫, 3]
# 20  [埔, li, xiu, lv, 車, mao, 煙, 開, 門, he, 見, yi, 對...     [煙, 歲, 開]
# 21  [quan, qiu, gu, shi, bu, 斷, geng, xin, ｜, mei,...    [大, 更新, ｜]
# 22  [zhi, tai, 灣, 當, xiao, di, shou, yi, miao, 鄭, ...     [小, 柯, 爆]
# 23  [zai, 嗆, ke, wen, 哲, shuai, 鍋, lin, you, chang...     [哲, 昌, 甩]
# 24  [bu, zhi, hao, xin, gan, ！, zhen, 興, 醫, yuan, ...    [8, 分享, 名]
# 25  [廣, gao, da, heng, bei, xiao, san, bao, 「, zuo...     [宮, 爆, 「]
# 26  [謝, 忻, yin, ta, chu, yi, 張, zui, 縫, 11, 針, 腳, ...     [」, 「, 嘴]
# 27  [諷, ci, ！, 彰, hua, li, 長, qi, qi, 壇, 驅, 疫, 4, ...    [妻, 宗教, 市]
# 28  [ping, 東, nv, 僅, chuan, 內, yi, yi, 門, bi, chu,...    [穿, 手, 內衣]
# 29  [bing, li, 總, zheng, li, ｜, da, yi, miao, 84, ...   [疫苗, 84, 東]
# 30  [撿, pian, yi, 懶, ren, bao, ｜, wu, 賀, la, 麵, ti...     [人, 麵, 拉]
# 31  [時, shang, ｜, PRADA, chun, xia, 滿, 滿, xiao, du...    [滿, 沒, 看秀]
# 32  [詩, ren, 吳, 岱, 穎, shui, 夢, zhong, 辭, shi, xian...     [辭, 睡, 中]
# 33  [he, 馨, gong, bu, zao, 「, 強, guan, 20, ping, 」...     [「, 講, 長]
# 34  [tai, nan, 檢, cha, 長, bao, te, 權, tou, da, yi,...   [長, 爆, 檢察官]
# 35  [《, 紐, 時, 》, ：, mei, juan, tai, 250, 萬, 劑, yi,...     [美, 係, 關]
# 36  [陳, qi, 邁, 搶, xian, xuan, bu, ！, gao, xiong, y...    [23, 這, 槍]
# 37  [yi, 圖, zhang, wo, yi, miao, jie, 種, 10, da, 順...    [選, 10, 先]
#
#                                               summary
# 0                                       [陳 其邁 搶 先 宣布]
# 1   [高嘉瑜 「 得寸 進尺 」 內容 曝光 5 度 傳訊北市 衛生 局長 為 禾 馨 喬 疫苗...
# 2                                          [陳 其 邁怒 了]
# 3          [友邦 巴拉圭 預購 100 萬劑 聯 亞 製 造 疫苗 就 等 台灣 緊急 授權]
# 4                                 [保單 紓 困 ｜ 比勞 工貸 優惠]
# 5                 [邱毅 赴 廈門 打 疫苗 讓 中國歡 呼盤點 這些 人 都 去 了]
# 6                          [米 砂裙 底露 餡 黑黑的 網驚 放大 照片 看]
# 7                                     [還好 辣個 男人 神 救援]
# 8                                   [黃 國昌籲 部長 總長 速究責]
# 9               [新婚 人 妻夜 奔 小 王家 「 玩手 遊 」 夫捉姦 驚見 滿屋 人]
# 10                [晶片 換 疫苗 全民 熱議 謝 金河 ： 台積 電是 有 威力 的]
# 11                     [傳播妹 昏睡 遭 熟客 性侵 怒問 「 為何 睡 我 」]
# 12                                            [雨彈 來襲]
# 13                                 [勞工 紓 困貸 ｜ 客訴 接不完]
# 14             [獨家 ｜ 台中 今 暴增 5 人 打 疫苗 後 死亡 盧秀燕 說 話 了]
# 15                     [台中 6 月 爆 10 起 死亡 車禍 7 件 是 超速]
# 16                                               [傻眼]
# 17                                         [又 是 冷藏 庫]
# 18  [迷姦 人 妻無恥 狡辯 「 是 我 被 下藥 」 診所 主任 判賠 129 萬 坐牢 10 年]
# 19  [士林 長 照 48 染疫 3 死給 柯 Ｐ 教訓 「 打過 疫苗 還 中招 、 普篩 潛伏...
# 20               [埔里 休旅車 冒 煙 開門 赫見 一 對 20 歲 男女 明顯 死亡]
# 21         [全球股市 不斷 更新 ｜ 美股 大跌 後 反攻 道瓊 早盤 大漲 逾 500 點]
# 22                [指台灣當 小弟 收 疫苗 鄭運鵬 兩句 話 酸 爆 柯文 哲高嘉瑜]
# 23                [再 嗆 柯文 哲 甩 鍋林 右昌 ： 我 是 真的 覺得 很 不爽]
# 24                                          [不 只好 心肝]
# 25                [廣告 大亨 被 小三爆 「 做 愛不戴套 」 正宮 驚 收親 密照]
# 26                 [謝忻因 他 出 一張 嘴縫 11 針腳 爆血 「 啵 啵 」 流]
# 27                                               [諷刺]
# 28                   [屏東 女僅 穿 內衣 倚門 比出 「 1 」 手勢 玩完 惹]
# 29             [病例 總 整理 ｜ 打 疫苗 84 人 猝死 屏東 嬤 早上 接種 疫苗]
# 30        [撿 便宜 懶人包 ｜ 五賀 拉 麵 挺 醫護 人員外 帶 拉 麵 品項 半價 優惠]
# 31  [時尚 ｜ PRADA 春夏 滿滿 小 短褲 男 李鍾碩 、 櫻田通 在 線 看秀 沒先來 ...
# 32                            [詩人 吳岱穎 睡夢中 辭世 享年 45 歲]
# 33  [禾馨 公布 遭 「 強灌 20 瓶 」 關鍵 對 話 衛生局 ： 市長 講今 一定 要 打...
# 34                                  [黃 國昌籲 部長 總長 速究責]
# 35             [《 紐時 》 ： 美捐台 250 萬劑 疫苗 美中關 係 恐 更 緊 繃]
# 36                                      [陳 其邁 搶 先 宣布]
# 37     [一圖 掌握 疫苗 接種 10 大順位 孕婦 即 起 優先 打 、 任選 莫德納 或 AZ]
