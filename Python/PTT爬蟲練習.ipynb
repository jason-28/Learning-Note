# %%
import requests
from bs4 import BeautifulSoup
title=[]
url='https://pttbuy.cc/shoes/'
for page in range(1,10):
    res=requests.get(url)
    soup=BeautifulSoup(res.text,'html.parser')
    data=soup.select('a')
    paging=soup.select('.brdbtn')
    last_url=paging[1]['href']
    url=last_url
    for item in data:
        title.append(item.text)
        print(item.text)
# Out:
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [問題] converse的鞋標數字
# [問題] 求LBJ18情報
# [問題] 求問adidas有橘標的這雙白色跑鞋
# [問題] NIKE官網結帳掛掉了嗎？
# [公告] 簡易真假辨認、鞋版常用工具 & 文章標題分類
# [公告] 版規(ver.070123） 請務必遵守!!
# [公告] 置底推文 "買賣徵換" 開放試行
# [公告] 本版禁止贗品/假鞋之討論
# Re: [真假] Y拍賣場分享
# 最舊
# ‹ 上頁
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [問題] AJ1 女生尺寸詢問
# [問題] 問一雙編織NIKE
# [問題] 鞋評真的有在打球嗎??
# air max 97 產地疑問
# 蝦皮賣家真假
# [討論] 能接受放多久的庫存鞋？
# [問題] 請問北部NB門市哪裡還有2002RD(藍色)
# Re: [問題] 鞋評真的有在打球嗎??
# [情報] adidas官網
# [問題] 請問Y拍賣家真假
# [心得] 開箱 NIKE DUNK LOW BY YOU
# [問題] 請問蝦皮賣場真假（misaka.tw）
# [問題] 請問哪裡還有賣NB ML574TYA us8.5？
# [問題] 私立高校 蝦皮賣場真假
# [問題] 求推薦US13穿搭/慢跑鞋
# [心得] 開箱木曜4超玩 x V-TEX 聯名Rising防水鞋
# [討論] 請問這雙converse這樣是正常的嗎？
# [問題] 請問目前帆船鞋有推薦什麼品牌嗎？
# [心得] 開箱 NIKE ZOOM G.T CUT EP
# [問題] Nike dunk low 尺寸請益
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [問題] 驗鞋app的準確性?
# [問題] 請問Y拍賣家真假（PREZ 美日歐代購）
# [問題] NIKE Metcon系列哪裡買？（台北）
# [問題] 問一款MERRELL的鞋子
# [問題] 蝦皮店家Xiaolu select 馬汀鞋
# Re: [問題] Greats BAB 鞋款
# [問題] 請問這雙Nike的型號
# Re: [討論] 請問有人有買 gelhoop v13 嗎
# [情報] KD14
# [問題] 請問蝦皮賣家真假（S.M.P)
# [問題] 詢問Nike 型號
# [心得] New balance hierro V6 MTHIERW6
# [問題] 請問這雙Jordan籃球鞋型號
# [問題] 請問nike型號 氣墊 復古 白鞋
# [心得] Salomon S/LAB XT-6 簡單開箱
# [問題] 求解球鞋品牌型號？
# [問題] 想請問北部的實體店哪裡有992GR呢？
# [討論] Etonic的鞋好穿嗎?
# [討論] 籃球鞋頂腳趾的問題怎解
# [問題] 適合餐廳外場的舒適鞋款
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [問題] triple s顏色問題
# [問題] 請問這雙是什麼鞋？
# [討論] 請問Reebok的鞋好穿嗎？
# [問題] 熊貓dunk low
# [問題] SB Dunk Low Thunderstorm還找得到嗎？
# [問題] 請問蝦皮賣家真假
# Re: [問題] 有gore-tex 和 Vibram 的鞋
# [問題] 籃球鞋底變的很滑有解嗎？
# □ [情報] Zion Williamson一代
# [問題] 街舞battle上看到的兩雙鞋
# [問題] AJ1 low White Camo 尺寸請益
# Re: [情報] NIKE GT 系列籃球鞋 lineup
# [問題] Adidas尺寸挑選問題
# [問題] 這雙nike的型號是?
# [問題] 蝦皮店家真偽
# [情報] Adidas x Neighborhood x Undefeated
# [問題] 鞋子太寬的問題
# [情報] NIKE AF1 PAISLEY SWOOSH 變形蟲即將登場
# [問題] 官網訂購的nb327白絲綢外觀問題
# AJ11 低筒 淺藍 復刻
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [問題] NB 993求驗 感謝
# [問題] 音樂祭完 nb 996 麂皮清潔方法
# [分享] Timberland 金卡會員分享
# [問題] Hybrid S2 台北哪還找得到
# [問題] 請問這是亞瑟士那雙鞋
# [問題] HBX 折扣商品
# [討論] OUTLET現在還有flightposite嗎?
# [問題] Nike air max270氣墊破洞
# [問題] 蝦皮賣場真假
# [情報] NIKE GT 系列籃球鞋 lineup
# [問題] PG4買來當訓練鞋？
# [問題] 1970皮革款是限量或是國外限定嗎
# Fw: [情報] 三重墨達人牛仔褲、運動鞋、童鞋特賣會
# [情報] New balance 327補貨資訊
# [問題] 蝦皮賣場問題
# Re: [問題] 有gore-tex 和 Vibram 的鞋
# [心得] GAT outdoor德訓改鞋心得
# 993尺寸 請益
# [問題] Nike運動鞋挑選
# [討論] 台灣SNKRS是不是被連坐了
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [討論] 中國人瘋狂下單NIKE
# [問題] 這是什麼鞋子？(笑臉+數字)
# [問題] Y拍 汪星人
# [問題] 有gore-tex 和 Vibram 的鞋
# [情報] KD14……?
# [問題] 這是什麼鞋Ecco
# [問題] 這是什麼鞋？
# [問題] 請問蝦皮賣家Insane21-Japan商品真假
# [問題] 請問此賣場的鞋子真假?
# [問題] 請推薦硬鞋墊
# [問題] Nike air max 1版型
# [問題] 久站鞋MERRELL&ASICS
# [問題] 類似fitflop休閒鞋
# [問題] NB 992BL求驗 謝謝！
# [問題] nike air zoom hyperattack
# [問題] 幾個蝦皮賣家真假
# R: [心得] lebron 17 low
# [問題]拇指外翻怎麼挑鞋
# [問題] 蝦皮賣場真假
# [情報] New balance 574元祖灰補貨
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [情報] 林口三井OUTLET瞎逛
# [問題] 請問Aquafeb 賣鞋真假
# [討論] 哪裡可買nike zoom hyperflight premium?
# [問題] Suicoke Moto Vs 拖鞋尺寸選擇
# [討論] 粉色情侶鞋推薦
# [問題] 請問鞋款
# [問題] kobe v 復刻都是限量的嗎？
# [討論] lotto與固特異這樣算致敬嗎？
# [情報] NIKE KYRIE LOW 4
# [心得] Nike Air Max 1
# [情報] New Balance 327奶茶/灰白/粉色補貨資訊
# [情報] PUMA COURT RIDER/ALL-PRO KUZMA LOW
# [情報] Off-White x Converse Chuck 70 補貨
# [分享] 林果良品 生日優惠
# [問題] Puma Clyde All-Pro
# [問題] 請問路人鞋子型號
# [問題] Timberland地球守護者15551保養
# [討論] 市售籃球鞋有愈來愈差嗎?
# [討論] 中國開始抵制Nike？
# Re: [討論] 市售籃球鞋有愈來愈差嗎?
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# [問題] 請問找雙鞋是什麼型號？
# [討論] M991NV鞋底突起
# [推薦] New balance 996、997詳細講解影片
# [問題] 溢膠請益
# 林果良品生日優惠
# [問題] 請問蝦皮賣家迷惘美 真假
# [分享] Timberland金卡會員分享
# [問題] New Balance 2002RC 尺寸
# [問題] 哪裏還找的到飛馬37 好看的配色
# [討論] 有沒有長很像太空鞋 但比太空鞋便宜的款?
# [情報] NIKE AIR MAX PRE-DAY
# 詢問鞋款型號
# [討論] Nike Air Max 1 x CLOT KOD 新色CHA
# [問題] 有類似Nike React的鞋墊嗎？
# [問題] Palladium 高筒皮鞋 真假 鞋底
# [情報] NIKE ZOOM G.T. CUT
# [問題] 請問蝦皮賣家真假
# [問題] 蝦皮賣家真假
# [新聞] 神宿 擔任adidas x ABC-MART合作新系列
# [問題]北部推薦 洗鞋店Nike air Max react270
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc
# PTT消費區
# 看板列表
# 熱門文章
# 最新文章
# 首頁
# shoes
# Re: [問題] 亂跑跳型籃球鞋款詢問
# [問題] 求扁平足適合久站的運動鞋
# [問題] asics鞋 蝦皮賣家真假
# Re: [問題] Tmac2上市時間？
# [問題] Kybrid s2求驗
# [問題] Yeezy boot 700 v2 Cream 尺寸建議
# [討論] 鞋子太亮反光 可以用什麼方法(例:消光漆)
# [問題] 網站球鞋真假
# [問題] Nike Zoom Winflo 6
# [問題] Y-3 Notoma boot 實物請教
# [討論] Nova Surge 小拇指很緊
# [問題] 蝦皮賣家真假
# [討論] New balance327是不是炒的有點太誇張了
# [問題] NB 993尺寸請益
# [問題] 芭蕾舞鞋款哪裡找?
# Palladium會員卡號分享
# [問題] Chuck 70 Bosey GTX維修
# [問題] 補教業上課鞋子推薦
# [問題] 請問蝦皮賣家真假
# [問題] 請問蝦皮真假
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
# pttbuy.cc

# %%
paging[1]
# Out:
# <a class="brdbtn" href="https://pttbuy.cc/shoes/?page=1976" rel="prev">‹ 上頁</a>

# %%
paging[1]['href']
# Out:
# 'https://pttbuy.cc/shoes/?page=1976'

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] #設定字型避免錯誤
colrogroup = ['#427f8f','#4a8fa1','#559db0','#66a7b8','#77b1c0','#89bbc8','#9ac5d0','#bdd9e0','#cee3e8','#e0edf0']
#藍色漸層
colrogroup2 = ['#cd0003','#e60003','#ff0004','#ff1a1d','#ff3436','#ff4d4f','#ff6768','#ff8181','#ff9a9b','#ffb4b4']
#紅色漸層
shoes_brand = ['nike','adidas','balance','puma','acisc',
'converse','reebok','mizuno','kappa','fila', 'underarmour', 'vans', 'diadora']
brand_count=[]

for name in shoes_brand:
    count=0
    for metioned in title:
        if name in str(metioned):
            count+=1
    brand_count.append(count)

# %%
plt.bar(shoes_brand,brand_count,color=colrogroup)
plt.xticks(fontsize=15,rotation=90)
for index,data in enumerate(brand_count):
    plt.text(x=index,y=data,s=data,verticalalignment='top',horizontalalignment='center')
plt.xlabel('運動鞋品牌',fontsize=15)
plt.ylabel('聲量',fontsize=15)
plt.title('運動鞋品牌聲量分析',fontsize=20)
plt.show()

# %%
L = ['a','b','c']
for i in enumerate(L):
    print(i)
# Out:
# (0, 'a')
# (1, 'b')
# (2, 'c')

# %%
for index, data in enumerate(brand_count):
    print(index,data)
# Out:
# 0 4
# 1 3
# 2 5
# 3 0
# 4 0
# 5 2
# 6 0
# 7 0
# 8 0
# 9 0
# 10 0
# 11 0
# 12 0
